# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time
import hashlib

# %%
# 全局集合，用于存储已访问过的 URL
visited = set()
# 用于存储成功访问的 URL
successful_urls = []
# 用于存储每个页面内容的哈希值，去重使用
content_hashes = set()

# 计算页面内容的哈希值，避免重复
def get_content_hash(content):
    return hashlib.md5(content.encode('utf-8')).hexdigest()

# %%
# 定义递归函数，爬取每个页面
def crawl(url, base_url):
    # 如果已经访问过此URL，则跳过
    if url in visited:
        return
    visited.add(url)  # 记录访问过的URL

    # 请求页面内容
    try:
        response = requests.get(url)
        response.raise_for_status()  # 检查请求是否成功
    except requests.RequestException as e:
        print(f"Error accessing {url}: {e}")
        return

    # 计算页面内容的哈希值
    content_hash = get_content_hash(response.text)

    # 如果该页面内容的哈希值已经存在，说明内容重复，跳过该页面
    if content_hash in content_hashes:
        print(f"Duplicate content found at: {url}, skipping.")
        return

    # 保存该页面内容的哈希值
    content_hashes.add(content_hash)

    # 如果访问成功且内容不重复，保存这个 URL
    successful_urls.append(url)
    print(f"Successfully visited: {url}")

    # 解析页面
    soup = BeautifulSoup(response.text, 'html.parser')

    # 查找所有的链接，使用 'a' 标签
    for link in soup.find_all('a', href=True):
        # 获取链接的完整URL
        href = link.get('href')
        new_url = urljoin(url, href)  # 使用当前页面的 URL 作为基准

        # 检查是否为相同域名的链接
        if urlparse(new_url).netloc == urlparse(base_url).netloc:
            # 避免爬取无效的锚点链接和邮件链接
            if not new_url.endswith('#') and not new_url.startswith('mailto:'):
                # 去除 URL 中的片段（#及其后内容）
                new_url = new_url.split('#')[0]
                # 去除 URL 中的查询参数（?及其后内容），如果不需要可以保留
                new_url = new_url.split('?')[0]
                # 递归爬取新的页面
                crawl(new_url, base_url)

    # 爬取结束后，稍作休眠
    time.sleep(1)  # 避免爬虫过快爬取

# %%
start_url = "https://tugraph-db.readthedocs.io/zh-cn/latest/"
crawl(start_url, start_url)

# 将成功访问的 URL 保存到文件
with open("../data/successful_urls.txt", "a", encoding='utf-8') as f:
    for url in successful_urls:
        f.write(url + "\n")

print(f"Successfully saved {len(successful_urls)} unique URLs to 'successful_urls.txt'.")
# Out:
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/1.guide.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/index.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/index.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/1.what-is-graph.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/2.what-is-gdbms.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/3.what-is-tugraph.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/4.schema.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/5.characteristics/index.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/5.characteristics/1.performance-oriented.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/5.characteristics/2.multi-level-Interfaces.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/5.characteristics/3.htap.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/6.architecture.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/7.functionality.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/8.scenarios.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/2.introduction/9.glossary.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/index.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/1.preparation.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/2.demo/index.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/2.demo/1.movie.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/2.demo/2.wandering-earth.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/2.demo/3.the-three-body.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/2.demo/4.three-kingdoms.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/3.quick-start/2.demo/5.round-the-world.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/4.user-guide/index.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/4.user-guide/1.tugraph-browser.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/4.user-guide/2.tugraph-browser-legacy.html
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/7.client-tools/2.cpp-client.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/7.client-tools/1.python-client.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/7.client-tools/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/9.restful.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/8.tugraph-explorer.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/7.tugraph-datax.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/6.tugraph-cli.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/5.ha-cluster-management.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/4.data-warmup.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/3.backup-and-restore.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/2.data-export.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/1.data-import.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/6.utility-tools/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/8.high-availability-mode.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/7.tugraph-running.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/6.compile.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/5.cloud-deployment.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/4.local-package-deployment.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/3.docker-deployment.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/2.environment-mode.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/1.environment.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/5.installation&running/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/development_guide.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/4.user-guide/2.tugraph-browser-legacy.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/4.user-guide/1.tugraph-browser.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/4.user-guide/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/2.demo/5.round-the-world.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/2.demo/4.three-kingdoms.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/2.demo/3.the-three-body.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/2.demo/2.wandering-earth.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/2.demo/1.movie.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/2.demo/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/1.preparation.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/3.quick-start/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/9.glossary.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/8.scenarios.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/7.functionality.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/6.architecture.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/5.characteristics/3.htap.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/5.characteristics/2.multi-level-Interfaces.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/5.characteristics/1.performance-oriented.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/5.characteristics/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/4.schema.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/3.what-is-tugraph.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/2.what-is-gdbms.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/1.what-is-graph.md.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/2.introduction/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/index.rst.txt
# Successfully visited: https://tugraph-db.readthedocs.io/zh-cn/latest/_sources/1.guide.md.txt
# Successfully saved 203 unique URLs to 'successful_urls.txt'.

# %%
start_url = "https://www.oceanbase.com/docs/tugraph-doc-cn"

crawl(start_url, start_url)

# 将成功访问的 URL 保存到文件
with open("../data/successful_urls.txt", "a", encoding='utf-8') as f:
    for url in successful_urls:
        f.write(url + "\n")

print(f"Successfully saved {len(successful_urls)} unique URLs to 'successful_urls.txt'.")
# Out:
# Successfully visited: https://www.oceanbase.com/docs/tugraph-doc-cn
# Successfully saved 204 unique URLs to 'successful_urls.txt'.
